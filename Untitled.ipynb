# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\hp\anaconda3\lib\site-packages (0.3.8)
# Requirement already satisfied: Pillow in c:\users\hp\anaconda3\lib\site-packages (from pytesseract) (8.2.0)

# %%
import pytesseract
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = path

# %%
path = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img = Image.open('OneDrive\Pictures/a.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1012x645 at 0x2593EB11FD0>

# %%
text = pytesseract.image_to_string(img)
text
# Out:
# 'What will be the output printed by the following program?\n#include<stdio.h>\n\nint main( )\n\nchar s[ ] = { ‘a’’b\'\'c\'\\n\'\'c\',\\n\'} // ASCII code \\n=10 ,a=97\nchar *fu,*hu,*lu;\n\nu= &s[3];\nhu = fu;\nu=s\n\nprintf("%d", ++ *fu + ++ *lu -32);\n\n \n\nType your answer here\n\x0c'

# %%
print(text)
# Out:
# What will be the output printed by the following program?
# #include<stdio.h>
#
# int main( )
#
# char s[ ] = { ‘a’’b''c'\n''c',\n'} // ASCII code \n=10 ,a=97
# char *fu,*hu,*lu;
#
# u= &s[3];
# hu = fu;
# u=s
#
# printf("%d", ++ *fu + ++ *lu -32);
#
#
#
# Type your answer here
